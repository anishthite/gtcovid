# %%
import requests
import pandas as pd
import lxml
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
page = requests.get('http://health.gatech.edu/coronavirus/health-alerts')

# %%
page = page.text[page.text.index('<h3>Current Month</h3>'):]
dfs = pd.read_html(page)

# %%
megadf = pd.concat(dfs)

# %%
megadf
# Out:
#       Date Reported      Position          Date Last on Campus  \
# 0   August 11, 2020       Student              August 10, 2020
# 1   August 10, 2020       Student  Currently living off campus
# 2   August 10, 2020       Student                 May 11, 2020
# 3   August 10, 2020         Staff                          NaN
# 4    August 8, 2020       Student               August 6, 2020
# ..              ...           ...                          ...
# 11   March 27, 2020  Staff member                March 9, 2020
# 12   March 26, 2020       Student               March 13, 2020
# 13   March 26, 2020       Student               March 12, 2020
# 14   March 25, 2020  Staff member               March 18, 2020
# 15   March 23, 2020       Student               March 18, 2020
#
#                                         Campus Impact
# 0   The student lives off campus; all affected ind...
# 1   The student lives off campus and hasn’t had an...
# 2   The student hasn’t had any campus contacts; no...
# 3   The individual works off site and out of state...
# 4   The infection occurred in early July; no campu...
# ..                                                ...
# 11  Electrical and Computer Engineering building. ...
# 12  The student reported that their symptoms start...
# 13  The student reported that their symptoms start...
# 14  Paper Tricentennial Building as part of the Re...
# 15                            Stamps Health Services.
#
# [161 rows x 4 columns]

# %%
megadf["Date Reported"] = megadf["Date Reported"].astype("datetime64")
megadf.groupby(megadf["Date Reported"].dt.week)[['Date Reported']].count()[:-1].plot(kind="line",legend=None,title="New Covid-19 Cases at GT",figsize=(15,5)).set_xlabel('Week Number')
plt.savefig('gtweekly.png')
megadf.groupby(megadf["Date Reported"].dt.date)[['Date Reported']].count().plot(kind="line",legend=None,title="New Covid-19 Cases at GT",figsize=(15,5)).set_xlabel('Date')
plt.savefig('gtdaily.png')
megadf.groupby(megadf["Date Reported"].dt.date)[['Date Reported']].count().rolling(10).mean().plot(kind="line",legend=None,title="New Covid-19 Cases at GT (10 day rolling mean)",figsize=(15,5)).set_xlabel('Date')
plt.savefig('gtdaily10day.png')

# %%
megadf.groupby(megadf["Position"])[['Position']].count()[:-1].plot(kind="bar",title="Amount of Covid-19 Cases at GT",figsize=(10,3))

# %%
only_counts = megadf.groupby(megadf["Date Reported"].dt.week)[['Date Reported']].count()[:-1]

ys = only_counts.iloc[:,0].to_numpy()
xs = np.arange(len(ys))
x_space = np.linspace(0,len(ys)+3)

coef = np.polyfit(xs,ys,3,full=True)
poly = np.poly1d(coef[0])
y_pred = poly(xs)
r2_score(ys,y_pred)
# Out:
# 0.8486278407001768

# %%
y_space = poly(x_space)
plt.plot(x_space,y_space,ys)
# Out:
# [<matplotlib.lines.Line2D at 0x7fc9be614bd0>,
#  <matplotlib.lines.Line2D at 0x7fc9be5d6a50>]

# %%
xs = np.arange(len(ys))
plt.plot(xs,ys,y_pred)
# Out:
# [<matplotlib.lines.Line2D at 0x7fc9be5c9250>,
#  <matplotlib.lines.Line2D at 0x7fc9be5c9fd0>]
